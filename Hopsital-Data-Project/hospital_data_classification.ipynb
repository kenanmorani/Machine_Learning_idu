# %% [markdown]
# <a href="https://colab.research.google.com/github/kenanmorani/Machine_Learning_idu/blob/main/Hopsital-Data-Project/hospital_data_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install turicreate
# Out:
# ...
#      |████████████████████████████████| 92.0MB 47kB/s
# ...
#      |████████████████████████████████| 327kB 49.4MB/s
# ...
#      |████████████████████████████████| 3.4MB 42.6MB/s
# ...
#      |████████████████████████████████| 86.4MB 60kB/s
# ...
#      |████████████████████████████████| 3.8MB 39.1MB/s
# ...
#      |████████████████████████████████| 51kB 5.9MB/s
# ...
#      |████████████████████████████████| 450kB 36.2MB/s
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-cp36-none-any.whl size=13702 sha256=957b34e987298dd2ff4558394390b08e9c218726e4bac7ffaf12d8219612aac7
#   Stored in directory: /root/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# ...
#   Created wheel for resampy: filename=resampy-0.2.1-cp36-none-any.whl size=320849 sha256=67f60540f578202b79aec5263ed29676bd121ed7a3e5ce5cc7e1494c5dbfc7dd
#   Stored in directory: /root/.cache/pip/wheels/ff/4f/ed/2e6c676c23efe5394bb40ade50662e90eb46e29b48324c5f9b
# ...

# %%
import pandas as pd
import turicreate

# %%
data = turicreate.SFrame.read_csv('bank.csv')
Hospital_data = turicreate.SFrame.read_csv('hospital.csv')
# Out:
# Read 100 lines. Lines per second: 2269.07
# Finished parsing file /content/bank.csv
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Parsing completed. Parsed 100 lines in 0.045234 secs.
# Finished parsing file /content/bank.csv
# Parsing completed. Parsed 4521 lines in 0.036857 secs.
# Finished parsing file /content/hospital.csv
# Parsing completed. Parsed 100 lines in 0.035934 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,str,int,str]
# If parsing fails due to incorrect types, you can correct
# ...

# %%
Hospital_data.head()
# Out:
# Columns:
# 	Patient identifier	int
# 	Is the patient alive or not	str
# 	Date of death	str
# 	Sex	str
# 	Date of birth	str
# 	PCI is happened or not	str
# 	Reanimation before the hospitalization	str
# 	Cardiogen shock at hospitalization	str
# 	Myocardialis.infarctus in medical history	str
# 	Health failure in medical history	str
# 	Hypertonia in medical history or during the treatment	str
# 	Stroke in medical history	str
# 	Diabetes in medical history	str
# 	Peripherial vascular disease in medical history	str
# 	Hyperlipidaemia in medical history	str
# 	Smoker in medical history	str
# 	Creatinin level	str
# 	Diagnosis	str
# 	Treatment identifier	int
# 	Date of hospitalization	str
#
# Rows: 10
#
# Data:
# +--------------------+-----------------------------+---------------+--------+
# | Patient identifier | Is the patient alive or not | Date of death |  Sex   |
# +--------------------+-----------------------------+---------------+--------+
# ...

# %%
# Uploading the csv file 
# Using sep is necessary to show the table well organized
#bank_data = pd.read_csv('bank.csv', sep=';') 
#bank_data
# Out:
#       age            job  marital  education  ... pdays  previous poutcome   y
# 0      30     unemployed  married    primary  ...    -1         0  unknown  no
# 1      33       services  married  secondary  ...   339         4  failure  no
# 2      35     management   single   tertiary  ...   330         1  failure  no
# 3      30     management  married   tertiary  ...    -1         0  unknown  no
# 4      59    blue-collar  married  secondary  ...    -1         0  unknown  no
# ...   ...            ...      ...        ...  ...   ...       ...      ...  ..
# 4516   33       services  married  secondary  ...    -1         0  unknown  no
# 4517   57  self-employed  married   tertiary  ...    -1         0  unknown  no
# 4518   57     technician  married  secondary  ...    -1         0  unknown  no
# 4519   28    blue-collar  married  secondary  ...   211         3    other  no
# 4520   44   entrepreneur   single   tertiary  ...   249         7    other  no
#
# ...

# %%
# Converting the file to pandas' dataframe type
#bank_data_frame = pd.DataFrame(bank_data)
#bank_data_frame
# Out:
#       age            job  marital  education  ... pdays  previous poutcome   y
# 0      30     unemployed  married    primary  ...    -1         0  unknown  no
# 1      33       services  married  secondary  ...   339         4  failure  no
# 2      35     management   single   tertiary  ...   330         1  failure  no
# 3      30     management  married   tertiary  ...    -1         0  unknown  no
# 4      59    blue-collar  married  secondary  ...    -1         0  unknown  no
# ...   ...            ...      ...        ...  ...   ...       ...      ...  ..
# 4516   33       services  married  secondary  ...    -1         0  unknown  no
# 4517   57  self-employed  married   tertiary  ...    -1         0  unknown  no
# 4518   57     technician  married  secondary  ...    -1         0  unknown  no
# 4519   28    blue-collar  married  secondary  ...   211         3    other  no
# 4520   44   entrepreneur   single   tertiary  ...   249         7    other  no
#
# ...

# %%
#bank_data_frame.head()
# Out:
#    age          job  marital  education  ... pdays  previous poutcome   y
# 0   30   unemployed  married    primary  ...    -1         0  unknown  no
# 1   33     services  married  secondary  ...   339         4  failure  no
# 2   35   management   single   tertiary  ...   330         1  failure  no
# 3   30   management  married   tertiary  ...    -1         0  unknown  no
# 4   59  blue-collar  married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]
