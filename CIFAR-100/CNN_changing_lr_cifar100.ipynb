# %% [markdown]
# <a href="https://colab.research.google.com/github/kenanmorani/Machine_Learning_idu/blob/main/CIFAR-100/CNN6_cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification on CIFAR-100 dataset
# # Machine Learning Course Final Project
# Izmir Democracy University, Electrical and Electronics Program
# Submitted to Assoc. Prof. Devrim Unay
# Submitted by Kenan MORANI
# Deadline for submission is on 3rd of February 2021

# %%
# Installing the required libraries
# !pip uninstall keras
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras) (1.15.0)

# %%
# Importing the required libraries
from __future__ import print_function
import keras
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
from keras.regularizers import l2
from keras.callbacks import Callback, LearningRateScheduler, TensorBoard, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras import backend as K
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
#Defining the required constants
BATCH_SIZE = 100
NUM_CLASSES = 100
EPOCHS = 50
INIT_DROPOUT_RATE = 0.5
MOMENTUM_RATE = 0.9
INIT_LEARNING_RATE = 0.01
L2_DECAY_RATE = 0.0005
CROP_SIZE = 32
LOG_DIR = './logs'
MODEL_PATH = './keras_cifar100_model.h5'

# %%
# Loading the data (CIFAR-100)
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step

# %%
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# (50000, 1) (10000, 1)

# %%
# Exploring the some images in the dataset
m=4
k=0
plt.figure(1)
for i in range(0,m):
  for j in range(0,m):
    plt.subplot2grid((m,m),(i,j))
    plt.imshow(x_train[k])
    k=k+1
plt.show()

# %%
# Modifying the type of datasets
y_train = to_categorical(y_train, NUM_CLASSES)
y_test = to_categorical(y_test, NUM_CLASSES)
print(y_train.shape,y_test.shape)
# Out:
# (50000, 100) (10000, 100)

# %%
# Scaling and Normalizing
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.0
x_test /= 255.0

# %%
# Building the model
model = Sequential()
model.add(ZeroPadding2D(4, input_shape=x_train.shape[1:]))
# Stack 1:
model.add(Conv2D(384, (3, 3), padding='same', kernel_regularizer=l2(0.01)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
# Stack 2:
model.add(Conv2D(384, (1, 1), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(384, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(640, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(640, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
# Stack 3:
model.add(Conv2D(640, (3, 3), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(768, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(768, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(768, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
# Stack 4:
model.add(Conv2D(768, (1, 1), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(896, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(896, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
# Stack 5:
model.add(Conv2D(896, (3, 3), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(1024, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(1024, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
# Stack 6:
model.add(Conv2D(1024, (1, 1), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Conv2D(1152, (2, 2), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
# Stack 7:
model.add(Conv2D(1152, (1, 1), padding='same', kernel_regularizer=l2(L2_DECAY_RATE)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(INIT_DROPOUT_RATE))
model.add(Flatten())
model.add(Dense(NUM_CLASSES))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 40, 40, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 40, 40, 384)       10752
# _________________________________________________________________
# activation (Activation)      (None, 40, 40, 384)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 20, 20, 384)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 20, 384)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 384)       147840
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 384)       590208
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 640)       983680
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 20, 640)       1639040
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 640)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 640)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 640)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 640)       3687040
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 10, 768)       1966848
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 10, 768)       2360064
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 768)       2360064
# _________________________________________________________________
# activation_2 (Activation)    (None, 10, 10, 768)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 768)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 768)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 768)         590592
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 896)         2753408
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 896)         3212160
# _________________________________________________________________
# activation_3 (Activation)    (None, 5, 5, 896)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 896)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 896)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 896)         7226240
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 3, 3, 1024)        3671040
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 3, 3, 1024)        4195328
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 3, 1024)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 1024)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 2, 2, 1024)        1049600
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 1152)        4719744
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 1152)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 1152)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 1, 1152)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 1, 1, 1152)        1328256
# _________________________________________________________________
# activation_6 (Activation)    (None, 1, 1, 1152)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 1152)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 1, 1152)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               115300
# _________________________________________________________________
# activation_7 (Activation)    (None, 100)               0
# =================================================================
# Total params: 42,607,204
# Trainable params: 42,607,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Building the learning rate changes function
def lr_scheduler(epoch, lr, step_decay = 0.1):
    return float(lr * step_decay) if epoch == 34.000 else lr

# %%
class StepLearningRateSchedulerAt(LearningRateScheduler):
    def __init__(self, schedule, verbose = 0): 
        super(LearningRateScheduler, self).__init__()
        self.schedule = schedule
        self.verbose = verbose
    
    def on_epoch_begin(self, epoch, logs=None): 
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
            
        lr = float(K.get_value(self.model.optimizer.lr))
        lr = self.schedule(epoch, lr)
       
        if not isinstance(lr, (float, np.float32, np.float64)):
            raise ValueError('The output of the "schedule" function ' 'should be float.')
        
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0: 
            print('\nEpoch %05d: LearningRateScheduler reducing learning ' 'rate to %s.' % (epoch + 1, lr))

# %%
def random_crop(img, random_crop_size):
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

# %%
def crop_generator(batches, crop_length, num_channel = 3):
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, num_channel))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
# Setting the optimizer
opt = SGD(lr=INIT_LEARNING_RATE, momentum=MOMENTUM_RATE)

# %%
# Defining the functions
lr_rate_scheduler = StepLearningRateSchedulerAt(lr_scheduler)
tensorboard = TensorBoard(log_dir=LOG_DIR, batch_size=BATCH_SIZE)
checkpointer = ModelCheckpoint(MODEL_PATH, monitor='val_loss', verbose=1, save_best_only=True)
# Out:
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.

# %%
# Compiling the model
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy', 'top_k_categorical_accuracy'])

# %%
# Data augmentation 
datagen = ImageDataGenerator(samplewise_center=True,
                             zca_whitening=True,
                             horizontal_flip=True
                            )
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:337: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
# Fitting data augmentation
datagen.fit(x_train)

# %%
# Building the datasets after augmentation 
train_flow = datagen.flow(x_train, y_train, batch_size=BATCH_SIZE)
train_flow_w_crops = crop_generator(train_flow, CROP_SIZE)
valid_flow = datagen.flow(x_train, y_train, batch_size=BATCH_SIZE)

# %%
# Fitting the model
h=model.fit_generator(train_flow_w_crops,
                    epochs=50,
                    steps_per_epoch=len(x_train) / BATCH_SIZE,
                    callbacks=[lr_rate_scheduler, tensorboard, checkpointer],
                    validation_data=valid_flow, 
                    validation_steps=(len(x_train) / BATCH_SIZE))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
#   6/500 [..............................] - ETA: 4:13 - loss: 10.7342 - accuracy: 0.0233 - top_k_categorical_accuracy: 0.0983WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1628s vs `on_train_batch_end` time: 0.3432s). Check your callbacks.
# 500/500 [==============================] - 355s 710ms/step - loss: 10.2640 - accuracy: 0.0416 - top_k_categorical_accuracy: 0.1650 - val_loss: 9.8457 - val_accuracy: 0.0631 - val_top_k_categorical_accuracy: 0.2113
#
# Epoch 00001: val_loss improved from inf to 9.84567, saving model to ./keras_cifar100_model.h5
# Epoch 2/50
# 500/500 [==============================] - 353s 707ms/step - loss: 9.3323 - accuracy: 0.0882 - top_k_categorical_accuracy: 0.2897 - val_loss: 8.7916 - val_accuracy: 0.1294 - val_top_k_categorical_accuracy: 0.3735
#
# Epoch 00002: val_loss improved from 9.84567 to 8.79160, saving model to ./keras_cifar100_model.h5
# Epoch 3/50
# 500/500 [==============================] - 354s 708ms/step - loss: 8.5660 - accuracy: 0.1320 - top_k_categorical_accuracy: 0.3797 - val_loss: 8.0530 - val_accuracy: 0.1893 - val_top_k_categorical_accuracy: 0.4607
#
# Epoch 00003: val_loss improved from 8.79160 to 8.05295, saving model to ./keras_cifar100_model.h5
# Epoch 4/50
# 500/500 [==============================] - 353s 707ms/step - loss: 7.8464 - accuracy: 0.1807 - top_k_categorical_accuracy: 0.4653 - val_loss: 7.2032 - val_accuracy: 0.2721 - val_top_k_categorical_accuracy: 0.5842
#
# Epoch 00004: val_loss improved from 8.05295 to 7.20324, saving model to ./keras_cifar100_model.h5
# Epoch 5/50
# 500/500 [==============================] - 354s 708ms/step - loss: 7.2571 - accuracy: 0.2196 - top_k_categorical_accuracy: 0.5256 - val_loss: 6.6236 - val_accuracy: 0.3136 - val_top_k_categorical_accuracy: 0.6360
#
# Epoch 00005: val_loss improved from 7.20324 to 6.62361, saving model to ./keras_cifar100_model.h5
# Epoch 6/50
# 500/500 [==============================] - 353s 707ms/step - loss: 6.7681 - accuracy: 0.2514 - top_k_categorical_accuracy: 0.5642 - val_loss: 6.1819 - val_accuracy: 0.3387 - val_top_k_categorical_accuracy: 0.6602
#
# Epoch 00006: val_loss improved from 6.62361 to 6.18194, saving model to ./keras_cifar100_model.h5
# Epoch 7/50
# 500/500 [==============================] - 353s 707ms/step - loss: 6.3142 - accuracy: 0.2842 - top_k_categorical_accuracy: 0.6021 - val_loss: 5.6736 - val_accuracy: 0.3862 - val_top_k_categorical_accuracy: 0.7113
#
# Epoch 00007: val_loss improved from 6.18194 to 5.67359, saving model to ./keras_cifar100_model.h5
# Epoch 8/50
# 500/500 [==============================] - 353s 707ms/step - loss: 5.9223 - accuracy: 0.3075 - top_k_categorical_accuracy: 0.6317 - val_loss: 5.4590 - val_accuracy: 0.3860 - val_top_k_categorical_accuracy: 0.7017
#
# Epoch 00008: val_loss improved from 5.67359 to 5.45895, saving model to ./keras_cifar100_model.h5
# Epoch 9/50
# 500/500 [==============================] - 353s 706ms/step - loss: 5.6109 - accuracy: 0.3229 - top_k_categorical_accuracy: 0.6481 - val_loss: 5.0994 - val_accuracy: 0.4092 - val_top_k_categorical_accuracy: 0.7292
#
# Epoch 00009: val_loss improved from 5.45895 to 5.09940, saving model to ./keras_cifar100_model.h5
# Epoch 10/50
# 500/500 [==============================] - 354s 708ms/step - loss: 5.3209 - accuracy: 0.3402 - top_k_categorical_accuracy: 0.6634 - val_loss: 4.7613 - val_accuracy: 0.4345 - val_top_k_categorical_accuracy: 0.7564
#
# Epoch 00010: val_loss improved from 5.09940 to 4.76132, saving model to ./keras_cifar100_model.h5
# Epoch 11/50
# 500/500 [==============================] - 353s 706ms/step - loss: 5.0726 - accuracy: 0.3515 - top_k_categorical_accuracy: 0.6744 - val_loss: 4.5416 - val_accuracy: 0.4464 - val_top_k_categorical_accuracy: 0.7632
#
# Epoch 00011: val_loss improved from 4.76132 to 4.54155, saving model to ./keras_cifar100_model.h5
# Epoch 12/50
# 500/500 [==============================] - 353s 707ms/step - loss: 4.8315 - accuracy: 0.3653 - top_k_categorical_accuracy: 0.6852 - val_loss: 4.3086 - val_accuracy: 0.4614 - val_top_k_categorical_accuracy: 0.7749
#
# Epoch 00012: val_loss improved from 4.54155 to 4.30857, saving model to ./keras_cifar100_model.h5
# Epoch 13/50
# 500/500 [==============================] - 353s 706ms/step - loss: 4.6384 - accuracy: 0.3732 - top_k_categorical_accuracy: 0.6954 - val_loss: 4.1118 - val_accuracy: 0.4733 - val_top_k_categorical_accuracy: 0.7831
#
# Epoch 00013: val_loss improved from 4.30857 to 4.11178, saving model to ./keras_cifar100_model.h5
# Epoch 14/50
# 500/500 [==============================] - 351s 702ms/step - loss: 4.4770 - accuracy: 0.3744 - top_k_categorical_accuracy: 0.6989 - val_loss: 4.0392 - val_accuracy: 0.4613 - val_top_k_categorical_accuracy: 0.7744
#
# Epoch 00014: val_loss improved from 4.11178 to 4.03922, saving model to ./keras_cifar100_model.h5
# Epoch 15/50
# 500/500 [==============================] - 350s 701ms/step - loss: 4.3131 - accuracy: 0.3815 - top_k_categorical_accuracy: 0.7067 - val_loss: 3.8944 - val_accuracy: 0.4630 - val_top_k_categorical_accuracy: 0.7765
#
# Epoch 00015: val_loss improved from 4.03922 to 3.89435, saving model to ./keras_cifar100_model.h5
# Epoch 16/50
# 500/500 [==============================] - 352s 705ms/step - loss: 4.1498 - accuracy: 0.3922 - top_k_categorical_accuracy: 0.7167 - val_loss: 3.7118 - val_accuracy: 0.4826 - val_top_k_categorical_accuracy: 0.7893
#
# Epoch 00016: val_loss improved from 3.89435 to 3.71177, saving model to ./keras_cifar100_model.h5
# Epoch 17/50
# 500/500 [==============================] - 353s 706ms/step - loss: 4.0285 - accuracy: 0.3960 - top_k_categorical_accuracy: 0.7196 - val_loss: 3.5333 - val_accuracy: 0.5014 - val_top_k_categorical_accuracy: 0.8062
#
# Epoch 00017: val_loss improved from 3.71177 to 3.53330, saving model to ./keras_cifar100_model.h5
# Epoch 18/50
# 500/500 [==============================] - 353s 706ms/step - loss: 3.9018 - accuracy: 0.4040 - top_k_categorical_accuracy: 0.7247 - val_loss: 3.4365 - val_accuracy: 0.4964 - val_top_k_categorical_accuracy: 0.8076
#
# Epoch 00018: val_loss improved from 3.53330 to 3.43654, saving model to ./keras_cifar100_model.h5
# Epoch 19/50
# 500/500 [==============================] - 352s 704ms/step - loss: 3.8128 - accuracy: 0.4067 - top_k_categorical_accuracy: 0.7256 - val_loss: 3.3367 - val_accuracy: 0.5033 - val_top_k_categorical_accuracy: 0.8105
#
# Epoch 00019: val_loss improved from 3.43654 to 3.33669, saving model to ./keras_cifar100_model.h5
# Epoch 20/50
# 500/500 [==============================] - 352s 705ms/step - loss: 3.7110 - accuracy: 0.4105 - top_k_categorical_accuracy: 0.7331 - val_loss: 3.2378 - val_accuracy: 0.5117 - val_top_k_categorical_accuracy: 0.8124
#
# Epoch 00020: val_loss improved from 3.33669 to 3.23784, saving model to ./keras_cifar100_model.h5
# Epoch 21/50
# 500/500 [==============================] - 351s 703ms/step - loss: 3.6253 - accuracy: 0.4127 - top_k_categorical_accuracy: 0.7351 - val_loss: 3.1440 - val_accuracy: 0.5154 - val_top_k_categorical_accuracy: 0.8203
#
# Epoch 00021: val_loss improved from 3.23784 to 3.14397, saving model to ./keras_cifar100_model.h5
# Epoch 22/50
# 500/500 [==============================] - 354s 708ms/step - loss: 3.5594 - accuracy: 0.4180 - top_k_categorical_accuracy: 0.7367 - val_loss: 3.0092 - val_accuracy: 0.5348 - val_top_k_categorical_accuracy: 0.8326
#
# Epoch 00022: val_loss improved from 3.14397 to 3.00915, saving model to ./keras_cifar100_model.h5
# Epoch 23/50
# 500/500 [==============================] - 352s 703ms/step - loss: 3.4797 - accuracy: 0.4234 - top_k_categorical_accuracy: 0.7420 - val_loss: 2.9946 - val_accuracy: 0.5186 - val_top_k_categorical_accuracy: 0.8239
#
# Epoch 00023: val_loss improved from 3.00915 to 2.99463, saving model to ./keras_cifar100_model.h5
# Epoch 24/50
# 500/500 [==============================] - 352s 704ms/step - loss: 3.4194 - accuracy: 0.4222 - top_k_categorical_accuracy: 0.7451 - val_loss: 2.9207 - val_accuracy: 0.5340 - val_top_k_categorical_accuracy: 0.8321
#
# Epoch 00024: val_loss improved from 2.99463 to 2.92066, saving model to ./keras_cifar100_model.h5
# Epoch 25/50
# 500/500 [==============================] - 352s 705ms/step - loss: 3.3729 - accuracy: 0.4220 - top_k_categorical_accuracy: 0.7439 - val_loss: 2.8832 - val_accuracy: 0.5251 - val_top_k_categorical_accuracy: 0.8263
#
# Epoch 00025: val_loss improved from 2.92066 to 2.88323, saving model to ./keras_cifar100_model.h5
# Epoch 26/50
# 500/500 [==============================] - 352s 705ms/step - loss: 3.3161 - accuracy: 0.4280 - top_k_categorical_accuracy: 0.7491 - val_loss: 2.8371 - val_accuracy: 0.5278 - val_top_k_categorical_accuracy: 0.8300
#
# Epoch 00026: val_loss improved from 2.88323 to 2.83711, saving model to ./keras_cifar100_model.h5
# Epoch 27/50
# 500/500 [==============================] - 354s 708ms/step - loss: 3.2739 - accuracy: 0.4309 - top_k_categorical_accuracy: 0.7476 - val_loss: 2.7865 - val_accuracy: 0.5376 - val_top_k_categorical_accuracy: 0.8330
#
# Epoch 00027: val_loss improved from 2.83711 to 2.78645, saving model to ./keras_cifar100_model.h5
# Epoch 28/50
# 500/500 [==============================] - 354s 709ms/step - loss: 3.2431 - accuracy: 0.4286 - top_k_categorical_accuracy: 0.7497 - val_loss: 2.7930 - val_accuracy: 0.5231 - val_top_k_categorical_accuracy: 0.8301
#
# Epoch 00028: val_loss did not improve from 2.78645
# Epoch 29/50
# 500/500 [==============================] - 354s 708ms/step - loss: 3.1880 - accuracy: 0.4325 - top_k_categorical_accuracy: 0.7526 - val_loss: 2.7844 - val_accuracy: 0.5265 - val_top_k_categorical_accuracy: 0.8230
#
# Epoch 00029: val_loss improved from 2.78645 to 2.78439, saving model to ./keras_cifar100_model.h5
# Epoch 30/50
# 500/500 [==============================] - 353s 707ms/step - loss: 3.1514 - accuracy: 0.4342 - top_k_categorical_accuracy: 0.7574 - val_loss: 2.7201 - val_accuracy: 0.5392 - val_top_k_categorical_accuracy: 0.8321
#
# Epoch 00030: val_loss improved from 2.78439 to 2.72014, saving model to ./keras_cifar100_model.h5
# Epoch 31/50
# 500/500 [==============================] - 355s 710ms/step - loss: 3.1234 - accuracy: 0.4354 - top_k_categorical_accuracy: 0.7578 - val_loss: 2.6322 - val_accuracy: 0.5478 - val_top_k_categorical_accuracy: 0.8405
#
# Epoch 00031: val_loss improved from 2.72014 to 2.63224, saving model to ./keras_cifar100_model.h5
# Epoch 32/50
# 500/500 [==============================] - 352s 704ms/step - loss: 3.0928 - accuracy: 0.4412 - top_k_categorical_accuracy: 0.7603 - val_loss: 2.5908 - val_accuracy: 0.5552 - val_top_k_categorical_accuracy: 0.8479
#
# Epoch 00032: val_loss improved from 2.63224 to 2.59081, saving model to ./keras_cifar100_model.h5
# Epoch 33/50
# 500/500 [==============================] - 353s 706ms/step - loss: 3.0775 - accuracy: 0.4386 - top_k_categorical_accuracy: 0.7589 - val_loss: 2.5952 - val_accuracy: 0.5469 - val_top_k_categorical_accuracy: 0.8425
#
# Epoch 00033: val_loss did not improve from 2.59081
# Epoch 34/50
# 500/500 [==============================] - 353s 706ms/step - loss: 3.0515 - accuracy: 0.4424 - top_k_categorical_accuracy: 0.7590 - val_loss: 2.5654 - val_accuracy: 0.5514 - val_top_k_categorical_accuracy: 0.8430
#
# Epoch 00034: val_loss improved from 2.59081 to 2.56536, saving model to ./keras_cifar100_model.h5
# Epoch 35/50
# 500/500 [==============================] - 353s 707ms/step - loss: 2.7208 - accuracy: 0.5118 - top_k_categorical_accuracy: 0.8175 - val_loss: 2.1848 - val_accuracy: 0.6449 - val_top_k_categorical_accuracy: 0.8984
#
# Epoch 00035: val_loss improved from 2.56536 to 2.18479, saving model to ./keras_cifar100_model.h5
# Epoch 36/50
# 500/500 [==============================] - 353s 706ms/step - loss: 2.5561 - accuracy: 0.5459 - top_k_categorical_accuracy: 0.8422 - val_loss: 2.1145 - val_accuracy: 0.6594 - val_top_k_categorical_accuracy: 0.9057
#
# Epoch 00036: val_loss improved from 2.18479 to 2.11447, saving model to ./keras_cifar100_model.h5
# Epoch 37/50
# 500/500 [==============================] - 347s 694ms/step - loss: 2.4814 - accuracy: 0.5623 - top_k_categorical_accuracy: 0.8532 - val_loss: 2.0838 - val_accuracy: 0.6636 - val_top_k_categorical_accuracy: 0.9093
#
# Epoch 00037: val_loss improved from 2.11447 to 2.08385, saving model to ./keras_cifar100_model.h5
# Epoch 38/50
# 500/500 [==============================] - 347s 693ms/step - loss: 2.4468 - accuracy: 0.5687 - top_k_categorical_accuracy: 0.8562 - val_loss: 2.0300 - val_accuracy: 0.6777 - val_top_k_categorical_accuracy: 0.9162
#
# Epoch 00038: val_loss improved from 2.08385 to 2.02996, saving model to ./keras_cifar100_model.h5
# Epoch 39/50
# 500/500 [==============================] - 348s 697ms/step - loss: 2.4041 - accuracy: 0.5783 - top_k_categorical_accuracy: 0.8609 - val_loss: 2.0076 - val_accuracy: 0.6825 - val_top_k_categorical_accuracy: 0.9188
#
# Epoch 00039: val_loss improved from 2.02996 to 2.00757, saving model to ./keras_cifar100_model.h5
# Epoch 40/50
# 500/500 [==============================] - 350s 700ms/step - loss: 2.3706 - accuracy: 0.5841 - top_k_categorical_accuracy: 0.8695 - val_loss: 1.9692 - val_accuracy: 0.6909 - val_top_k_categorical_accuracy: 0.9237
#
# Epoch 00040: val_loss improved from 2.00757 to 1.96921, saving model to ./keras_cifar100_model.h5
# Epoch 41/50
# 500/500 [==============================] - 350s 700ms/step - loss: 2.3502 - accuracy: 0.5850 - top_k_categorical_accuracy: 0.8678 - val_loss: 1.9492 - val_accuracy: 0.6920 - val_top_k_categorical_accuracy: 0.9232
#
# Epoch 00041: val_loss improved from 1.96921 to 1.94919, saving model to ./keras_cifar100_model.h5
# Epoch 42/50
# 500/500 [==============================] - 349s 699ms/step - loss: 2.3320 - accuracy: 0.5902 - top_k_categorical_accuracy: 0.8709 - val_loss: 1.9248 - val_accuracy: 0.6987 - val_top_k_categorical_accuracy: 0.9266
#
# Epoch 00042: val_loss improved from 1.94919 to 1.92483, saving model to ./keras_cifar100_model.h5
# Epoch 43/50
# 500/500 [==============================] - 352s 705ms/step - loss: 2.2996 - accuracy: 0.5965 - top_k_categorical_accuracy: 0.8744 - val_loss: 1.9048 - val_accuracy: 0.7022 - val_top_k_categorical_accuracy: 0.9276
#
# Epoch 00043: val_loss improved from 1.92483 to 1.90480, saving model to ./keras_cifar100_model.h5
# Epoch 44/50
# 500/500 [==============================] - 351s 702ms/step - loss: 2.2806 - accuracy: 0.6005 - top_k_categorical_accuracy: 0.8772 - val_loss: 1.8824 - val_accuracy: 0.7061 - val_top_k_categorical_accuracy: 0.9310
#
# Epoch 00044: val_loss improved from 1.90480 to 1.88237, saving model to ./keras_cifar100_model.h5
# Epoch 45/50
# 500/500 [==============================] - 348s 697ms/step - loss: 2.2555 - accuracy: 0.6041 - top_k_categorical_accuracy: 0.8798 - val_loss: 1.8716 - val_accuracy: 0.7071 - val_top_k_categorical_accuracy: 0.9312
#
# Epoch 00045: val_loss improved from 1.88237 to 1.87159, saving model to ./keras_cifar100_model.h5
# Epoch 46/50
# 500/500 [==============================] - 350s 700ms/step - loss: 2.2440 - accuracy: 0.6052 - top_k_categorical_accuracy: 0.8814 - val_loss: 1.8454 - val_accuracy: 0.7130 - val_top_k_categorical_accuracy: 0.9347
#
# Epoch 00046: val_loss improved from 1.87159 to 1.84542, saving model to ./keras_cifar100_model.h5
# Epoch 47/50
# 500/500 [==============================] - 350s 699ms/step - loss: 2.2276 - accuracy: 0.6100 - top_k_categorical_accuracy: 0.8835 - val_loss: 1.8254 - val_accuracy: 0.7186 - val_top_k_categorical_accuracy: 0.9360
#
# Epoch 00047: val_loss improved from 1.84542 to 1.82538, saving model to ./keras_cifar100_model.h5
# Epoch 48/50
# 500/500 [==============================] - 346s 693ms/step - loss: 2.2102 - accuracy: 0.6107 - top_k_categorical_accuracy: 0.8857 - val_loss: 1.8141 - val_accuracy: 0.7217 - val_top_k_categorical_accuracy: 0.9364
#
# Epoch 00048: val_loss improved from 1.82538 to 1.81409, saving model to ./keras_cifar100_model.h5
# Epoch 49/50
# 500/500 [==============================] - 348s 696ms/step - loss: 2.1957 - accuracy: 0.6136 - top_k_categorical_accuracy: 0.8875 - val_loss: 1.7973 - val_accuracy: 0.7256 - val_top_k_categorical_accuracy: 0.9375
#
# Epoch 00049: val_loss improved from 1.81409 to 1.79728, saving model to ./keras_cifar100_model.h5
# Epoch 50/50
# 500/500 [==============================] - 350s 700ms/step - loss: 2.1753 - accuracy: 0.6175 - top_k_categorical_accuracy: 0.8907 - val_loss: 1.7760 - val_accuracy: 0.7281 - val_top_k_categorical_accuracy: 0.9407
#
# Epoch 00050: val_loss improved from 1.79728 to 1.77596, saving model to ./keras_cifar100_model.h5

# %%
# Checking model's accuracy during training 
plt.plot(h.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('EPOCHS')
plt.ylabel('Accuracy')
plt.show()

# %%
# Checking model's loss during training 
plt.plot(h.history['loss'])
plt.title('Model Loss')
plt.xlabel('EPOCHS')
plt.ylabel('Loss')
plt.show()

# %%
# plotting accuracy on training and test sets
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(h.history['accuracy'], label='train')
pyplot.plot(h.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
# Plotting loss on training and test sets
from matplotlib import pyplot
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(h.history['loss'], label='train')
pyplot.plot(h.history['val_loss'], label='test')
pyplot.legend()

# %%
# evaluating the model
score_train = model.evaluate(x_train, y_train)
score_test = model.evaluate(x_test, y_test)
# Out:
# 1563/1563 [==============================] - 97s 62ms/step - loss: 8.8242 - accuracy: 0.0274 - top_k_categorical_accuracy: 0.1061
# 313/313 [==============================] - 20s 63ms/step - loss: 8.8496 - accuracy: 0.0263 - top_k_categorical_accuracy: 0.1041
# Test Accuracy: 884.9607%

# %%
# Making prediction using the model
predictions = model.predict(x_test, batch_size=100, verbose=1)
# Out:
# 100/100 [==============================] - 13s 133ms/step

# %%
# Return Label function
def return_label(one_hot_lab):
    op = np.zeros(len(one_hot_lab))
    for i in range(len(one_hot_lab)):
        op[i] = np.argmax(one_hot_lab[i])
    return op
pred_labels = return_label(predictions)

# Generate Confusion Matrix
def prep_confusion_matrix(y_test, y_pred, num_of_classes=100):
    op = np.zeros((num_of_classes, num_of_classes))
    for i in range(len(y_test)):
        op[int(y_test[i]),int(y_pred[i])] += 1
    return op
# De-one-hotting labels
y_tst_dh = return_label(y_test)
# Preparing the confusion Matrix
conf_mat = prep_confusion_matrix(y_tst_dh, pred_labels)

# %%
import pandas as pd
import seaborn as sn
# Plotting the Confusion Matrix
df_cm = pd.DataFrame(conf_mat, index = [i for i in range(100)],
                  columns = [i for i in range(100)])
plt.figure(figsize = (25,25))
sn.heatmap(df_cm, annot=True)
